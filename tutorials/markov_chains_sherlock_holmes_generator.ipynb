# %% [markdown]
# # Imports

# %%
import requests
import nltk.tokenize
import ml.core.repo_paths
import ml.core.download
import dataclasses
from typing import Dict, Generic, TypeVar, Collection, Callable, Iterable
import itertools
import random

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sophi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Getting corpus
#
# ## Downloading

# %%
artifact_dir_data_raw = ml.core.repo_paths.get_dir_artifacts_data_raw("markov_chains_sherlock_holmes_generator", create=True)
corpus_path = artifact_dir_data_raw / "cano.txt"
ml.core.download.download_http("https://sherlock-holm.es/stories/plain-text/cano.txt", corpus_path)
# Out:
# Downloading 'https://sherlock-holm.es/stories/plain-text/cano.txt' to c:\Users\sophi\Code\ml\artifacts\data\markov_chains_sherlock_holmes_generator\raw\cano.txt...
# 3.87MB [00:00, 8.92MB/s]
#   Download complete.

# %% [markdown]
# ## Tokenizing

# %%
words = []

with open(corpus_path, "r") as file:
    for line in file:
        words.extend(nltk.tokenize.word_tokenize(line.lower()))

print(words[:100])
# Out:
# ['the', 'complete', 'sherlock', 'holmes', 'arthur', 'conan', 'doyle', 'table', 'of', 'contents', 'a', 'study', 'in', 'scarlet', 'the', 'sign', 'of', 'the', 'four', 'the', 'adventures', 'of', 'sherlock', 'holmes', 'a', 'scandal', 'in', 'bohemia', 'the', 'red-headed', 'league', 'a', 'case', 'of', 'identity', 'the', 'boscombe', 'valley', 'mystery', 'the', 'five', 'orange', 'pips', 'the', 'man', 'with', 'the', 'twisted', 'lip', 'the', 'adventure', 'of', 'the', 'blue', 'carbuncle', 'the', 'adventure', 'of', 'the', 'speckled', 'band', 'the', 'adventure', 'of', 'the', 'engineer', "'s", 'thumb', 'the', 'adventure', 'of', 'the', 'noble', 'bachelor', 'the', 'adventure', 'of', 'the', 'beryl', 'coronet', 'the', 'adventure', 'of', 'the', 'copper', 'beeches', 'the', 'memoirs', 'of', 'sherlock', 'holmes', 'silver', 'blaze', 'the', 'yellow', 'face', 'the', 'stock-broker', "'s", 'clerk']

# %% [markdown]
# # Creating Markov chain from scratch

# %%
TState = TypeVar("TState")

@dataclasses.dataclass
class MarkovChain(Generic[TState]):
    _states: Dict[TState, Dict[TState, float]] = dataclasses.field(default_factory=dict)

    def insert_state(self, state: TState) -> None:
        if state not in self._states:
            self._states[state] = {}
    
    def states(self) -> Collection[TState]:
        return self._states.keys()
    
    def insert_transition(self, source: TState, destination: TState, initial: float) -> None:
        assert source in self._states
        assert destination in self._states

        if destination not in self._states[source]:
            self._states[source][destination] = initial

    def update_transition_weight(self, source: TState, destination: TState, updater: Callable[[float], float]) -> None:
        assert source in self._states
        assert destination in self._states
        assert destination in self._states[source]

        self._states[source][destination] = updater(self._states[source][destination])
    
    def get_transition_weight(self, source: TState, destination: TState) -> float:
        assert source in self._states
        assert destination in self._states
        assert destination in self._states[source]

        return self._states[source][destination]

    def get_state_transitions(self, source: TState) -> Collection[TState]:
        assert source in self._states

        return self._states[source].keys()

    def sum_state_transition_weights(self, source: TState) -> float:
        assert source in self._states

        return sum(self._states[source].values())

# %% [markdown]
# ## Creating Markov chain from the corpus

# %%
def create_unnormalized_markov_chain(words: Collection[str]) -> MarkovChain[str]:
    markov_chain = MarkovChain()

    for i in range(len(words) - 1):
        markov_chain.insert_state(words[i])
        markov_chain.insert_state(words[i + 1])
        markov_chain.insert_transition(words[i], words[i + 1], 0.0)
        markov_chain.update_transition_weight(words[i], words[i + 1], lambda weight: weight + 1.0)

    return markov_chain

def normalize_markov_chain(markov_chain: MarkovChain[str]) -> None:
    for state in markov_chain.states():
        weight_sum = markov_chain.sum_state_transition_weights(state)

        for next_state in markov_chain.get_state_transitions(state):
            markov_chain.update_transition_weight(state, next_state, lambda weight: weight / weight_sum)

def create_markov_chain(words: Collection[str]) -> MarkovChain[str]:
    markov_chain = create_unnormalized_markov_chain(words)
    normalize_markov_chain(markov_chain)
    return markov_chain

markov_chain = create_markov_chain(words)

for i in itertools.islice(markov_chain.states(), 5):
    print(f"State {i!r}:")

    for j in markov_chain.get_state_transitions(i):
        print(f"  {j!r}: {markov_chain.get_transition_weight(i, j):.3f}")
# Out:
# State 'the':
#   'complete': 0.000
#   'sign': 0.000
#   'four': 0.001
#   'adventures': 0.000
#   'red-headed': 0.000
#   'boscombe': 0.000
#   'five': 0.000
#   'man': 0.013
#   'twisted': 0.000
#   'adventure': 0.003
#   'blue': 0.001
#   'speckled': 0.000
#   'engineer': 0.000
#   'noble': 0.000
#   'beryl': 0.000
#   'copper': 0.000
#   'memoirs': 0.000
#   'yellow': 0.000
#   'stock-broker': 0.000
#   '``': 0.000
#   'musgrave': 0.000
#   'reigate': 0.000
#   'crooked': 0.000
#   'resident': 0.000
#   'greek': 0.000
#   'naval': 0.000
#   'final': 0.000
#   'return': 0.000
#   'empty': 0.000
#   'norwood': 0.000
#   'dancing': 0.000
#   'solitary': 0.000
#   'priory': 0.000
#   'six': 0.000
#   'three': 0.002
#   'golden': 0.000
#   'missing': 0.001
#   'abbey': 0.000
#   'second': 0.003
#   'hound': 0.001
#   'baskervilles': 0.000
#   'valley': 0.001
#   'cardboard': 0.000
#   'red': 0.001
#   'bruce-partington': 0.000
#   'dying': 0.000
#   'disappearance': 0.001
#   'devil': 0.001
#   'case-book': 0.000
#   'illustrious': 0.000
#   'blanched': 0.000
#   'mazarin': 0.000
#   'sussex': 0.000
#   'problem': 0.001
#   'creeping': 0.000
#   'lion': 0.000
#   'veiled': 0.000
#   'retired': 0.000
#   'science': 0.000
#   'lauriston': 0.000
#   'darkness': 0.002
#   'great': 0.003
#   'flower': 0.000
#   'prophet': 0.000
#   'avenging': 0.000
#   'reminiscences': 0.000
#   'conclusion': 0.001
#   'army': 0.000
#   'year': 0.001
#   'university': 0.000
#   'course': 0.001
#   'fifth': 0.000
#   'regiment': 0.000
#   'time': 0.005
#   'passes': 0.000
#   'enemy': 0.000
#   'same': 0.011
#   'campaign': 0.000
#   'berkshires': 0.000
#   'fatal': 0.000
#   'shoulder': 0.001
#   'bone': 0.000
#   'subclavian': 0.000
#   'hands': 0.001
#   'murderous': 0.000
#   'devotion': 0.000
#   'british': 0.001
#   'prolonged': 0.000
#   'base': 0.000
#   'wards': 0.000
#   'verandah': 0.000
#   'troopship': 0.000
#   'next': 0.002
#   'loungers': 0.000
#   'empire': 0.000
#   'strand': 0.000
#   'state': 0.001
#   'metropolis': 0.000
#   'country': 0.003
#   'latter': 0.002
#   'hotel': 0.001
#   'very': 0.006
#   'criterion': 0.000
#   'sight': 0.001
#   'exuberance': 0.000
#   'holborn': 0.000
#   'crowded': 0.000
#   'first': 0.008
#   'chemical': 0.000
#   'hospital': 0.000
#   'rooms': 0.000
#   'expense': 0.000
#   'fancy': 0.000
#   'remainder': 0.000
#   'laboratory': 0.000
#   'place': 0.003
#   'conversation': 0.000
#   'gentleman': 0.001
#   'matter': 0.011
#   'inexpressible': 0.000
#   'latest': 0.000
#   'effects': 0.000
#   'subjects': 0.000
#   'dissecting-rooms': 0.000
#   'objects': 0.000
#   'bleak': 0.000
#   'long': 0.002
#   'further': 0.000
#   'room': 0.011
#   'sound': 0.001
#   'question': 0.002
#   'significance': 0.000
#   'most': 0.006
#   'coat-sleeve': 0.000
#   'table': 0.005
#   'resulting': 0.000
#   'appearance': 0.000
#   'proportion': 0.000
#   'characteristic': 0.000
#   'vessel': 0.000
#   'contents': 0.001
#   'bottom': 0.001
#   'glass': 0.001
#   'old': 0.006
#   'microscopic': 0.000
#   'stains': 0.000
#   'blood': 0.001
#   'earth': 0.000
#   'penalty': 0.000
#   'sherlock': 0.000
#   'case': 0.007
#   'notorious': 0.000
#   "'police": 0.000
#   'past': 0.001
#   'prick': 0.000
#   'idea': 0.002
#   'ground': 0.002
#   'smell': 0.000
#   'dumps': 0.000
#   'worst': 0.001
#   'principal': 0.000
#   'player': 0.000
#   'gods': 0.000
#   'thing': 0.001
#   'way': 0.004
#   'deuce': 0.000
#   'apartments': 0.000
#   'terms': 0.000
#   'bargain': 0.000
#   'spot': 0.001
#   'following': 0.001
#   'best': 0.003
#   'morning': 0.004
#   'lowest': 0.000
#   'city': 0.001
#   'working': 0.000
#   'sofa': 0.001
#   'sitting-room': 0.001
#   'use': 0.001
#   'temperance': 0.000
#   'weeks': 0.000
#   'attention': 0.000
#   'prominence': 0.000
#   'reader': 0.000
#   'reticence': 0.000
#   'weather': 0.000
#   'monotony': 0.000
#   'little': 0.003
#   'learned': 0.000
#   'exactness': 0.000
#   'naivest': 0.000
#   'copernican': 0.000
#   'composition': 0.000
#   'solar': 0.000
#   'sun': 0.001
#   'lumber': 0.000
#   'knowledge': 0.000
#   'skilful': 0.000
#   'tools': 0.000
#   'highest': 0.000
#   'useful': 0.000
#   'moon': 0.001
#   'point': 0.002
#   'various': 0.000
#   'document': 0.000
#   'century': 0.000
#   'violin': 0.000
#   'fire': 0.002
#   'fellow': 0.002
#   'attempt': 0.000
#   'fiddle': 0.000
#   'chords': 0.000
#   'thoughts': 0.000
#   'music': 0.000
#   'playing': 0.000
#   'result': 0.001
#   'trial': 0.000
#   'subject': 0.001
#   '4th': 0.000
#   'landlady': 0.000
#   'unreasonable': 0.000
#   'bell': 0.002
#   'articles': 0.000
#   'heading': 0.000
#   'book': 0.001
#   'reasoning': 0.000
#   'deductions': 0.000
#   'writer': 0.000
#   'uninitiated': 0.000
#   'processes': 0.000
#   'possibility': 0.000
#   'other': 0.012
#   'nature': 0.001
#   'greatest': 0.001
#   'enquirer': 0.000
#   'history': 0.000
#   'trade': 0.000
#   'faculties': 0.000
#   'callosities': 0.000
#   'competent': 0.000
#   'magazine': 0.000
#   'theory': 0.000
#   'seclusion': 0.000
#   'underground': 0.000
#   'trades': 0.000
#   'article': 0.000
#   'theories': 0.000
#   'only': 0.003
#   'world': 0.004
#   'right': 0.002
#   'evidence': 0.001
#   'help': 0.000
#   'details': 0.001
#   'thousand': 0.000
#   'sort': 0.001
#   'train': 0.001
#   'air': 0.002
#   'tropics': 0.000
#   'natural': 0.000
#   'whole': 0.007
#   'window': 0.008
#   'busy': 0.000
#   'detection': 0.000
#   'topic': 0.000
#   'street': 0.003
#   'numbers': 0.000
#   'bearer': 0.000
#   'thought': 0.001
#   'number': 0.000
#   'roadway': 0.000
#   'stair': 0.001
#   'letter': 0.003
#   'conceit': 0.000
#   'blandest': 0.000
#   'practical': 0.000
#   'note': 0.001
#   'vacant': 0.000
#   'thread': 0.000
#   'fact': 0.002
#   'back': 0.002
#   'sea': 0.001
#   'marine': 0.000
#   'face': 0.002
#   'commissionaire': 0.000
#   'common': 0.000
#   'night': 0.005
#   'brixton': 0.000
#   'beat': 0.000
#   'house': 0.012
#   'door': 0.013
#   'front': 0.002
#   'body': 0.002
#   'name': 0.003
#   'smartest': 0.000
#   'scotland': 0.000
#   'pick': 0.000
#   'scent': 0.000
#   'calm': 0.000
#   'fit': 0.000
#   'credit': 0.000
#   'apathetic': 0.000
#   'house-tops': 0.000
#   'reflection': 0.000
#   'mud-coloured': 0.000
#   'difference': 0.000
#   'dull': 0.000
#   'melancholy': 0.000
#   'judgment': 0.000
#   'bleared': 0.000
#   'rain': 0.000
#   'garden': 0.002
#   'top': 0.002
#   'vain': 0.000
#   'proceedings': 0.000
#   'mystery': 0.001
#   'circumstances': 0.001
#   'pavement': 0.000
#   'sky': 0.000
#   'opposite': 0.000
#   'line': 0.001
#   'path': 0.002
#   'fringe': 0.000
#   'wet': 0.000
#   'police': 0.006
#   'quickness': 0.000
#   'pathway': 0.000
#   'detective': 0.001
#   'kitchen': 0.001
#   'left': 0.001
#   'dining-room': 0.001
#   'apartment': 0.000
#   'mysterious': 0.000
#   'presence': 0.001
#   'larger': 0.000
#   'absence': 0.000
#   'walls': 0.001
#   'stump': 0.000
#   'light': 0.003
#   'thick': 0.000
#   'single': 0.000
#   'boards': 0.000
#   'discoloured': 0.000
#   'floor': 0.002
#   'low': 0.001
#   'dead': 0.002
#   'main': 0.001
#   'doorway': 0.001
#   'murderer': 0.001
#   'death': 0.002
#   'examination': 0.000
#   'minuteness': 0.000
#   'soles': 0.000
#   'purposes': 0.000
#   'mortuary': 0.000
#   'stranger': 0.001
#   'palm': 0.000
#   'finger': 0.000
#   'stairs': 0.002
#   'e.': 0.000
#   'linen': 0.000
#   'extent': 0.000
#   'fly-leaf': 0.000
#   'guion': 0.000
#   'sailing': 0.000
#   'newspapers': 0.000
#   'american': 0.001
#   'hall': 0.004
#   'scene': 0.002
#   'atmosphere': 0.000
#   'removal': 0.000
#   'wall': 0.002
#   'paper': 0.002
#   'darkest': 0.000
#   'mantelpiece': 0.001
#   'brightest': 0.000
#   'female': 0.000
#   'covert': 0.000
#   'lost': 0.000
#   'distance': 0.000
#   'word': 0.001
#   'manoeuvres': 0.000
#   'meantime': 0.001
#   'constable': 0.000
#   'address': 0.001
#   'two': 0.004
#   'prime': 0.000
#   'finger-nails': 0.000
#   'former': 0.000
#   'german': 0.001
#   'nearest': 0.000
#   'driver': 0.000
#   'curb': 0.000
#   'marks': 0.001
#   'horse': 0.001
#   'outline': 0.000
#   'cab': 0.002
#   'height': 0.000
#   'length': 0.000
#   'clay': 0.000
#   'dust': 0.000
#   'level': 0.000
#   'smallest': 0.000
#   'sere': 0.000
#   'breadth': 0.000
#   'trichinopoly': 0.000
#   'writing': 0.000
#   'plaster': 0.000
#   'ash': 0.000
#   'skilled': 0.000
#   'gregson': 0.000
#   'florid': 0.000
#   'present': 0.001
#   'affair': 0.001
#   'more': 0.002
#   'cabman': 0.001
#   'object': 0.001
#   'woman': 0.003
#   'difficulties': 0.000
#   'situation': 0.001
#   'a': 0.000
#   'latin': 0.000
#   'earnest': 0.000
#   'score': 0.000
#   'increased': 0.000
#   'while': 0.000
#   'tragedy': 0.001
#   'rest': 0.002
#   'dingiest': 0.000
#   'narrow': 0.000
#   'office': 0.001
#   'horsehair': 0.000
#   'beginning': 0.001
#   "'white": 0.000
#   'holland': 0.000
#   'corner': 0.003
#   'glint': 0.000
#   'drains': 0.000
#   'utmost': 0.001
#   'worse': 0.001
#   'grave': 0.000
#   'typhoid': 0.000
#   'gate': 0.001
#   'murder': 0.001
#   'hounds': 0.000
#   'wolf': 0.000
#   'railings': 0.000
#   'pitch': 0.000
#   'station': 0.002
#   'lower': 0.001
#   'policeman': 0.000
#   'force': 0.000
#   'clue': 0.000
#   'blundering': 0.000
#   'dark': 0.001
#   'description': 0.000
#   'ring': 0.001
#   'finest': 0.000
#   'scarlet': 0.000
#   'colourless': 0.000
#   'many-sidedness': 0.000
#   'human': 0.000
#   'afternoon': 0.001
#   'concert': 0.000
#   'strangest': 0.000
#   'distorted': 0.000
#   'murdered': 0.000
#   'impression': 0.001
#   'depravity': 0.000
#   'victim': 0.001
#   'eyes': 0.001
#   'law': 0.002
#   'facts': 0.003
#   'power': 0.001
#   'truth': 0.003
#   'imagination': 0.000
#   'evening': 0.003
#   'brown': 0.000
#   'square': 0.000
#   'candle': 0.001
#   'suspicions': 0.000
#   'road': 0.003
#   'hope': 0.001
#   'finding': 0.000
#   'pistol': 0.000
#   'plot': 0.000
#   'correct': 0.000
#   'better': 0.001
#   'key': 0.002
#   'inside': 0.001
#   'lowlands': 0.000
#   'printer': 0.000
#   'direction': 0.001
#   'servant': 0.000
#   'sharp': 0.000
#   'latch': 0.000
#   'footfall': 0.000
#   'passage': 0.002
#   'sudden': 0.001
#   'drink': 0.000
#   'circus': 0.000
#   'lord': 0.001
#   'company': 0.001
#   'women': 0.000
#   'rightful': 0.000
#   'moment': 0.002
#   'heart': 0.001
#   'pages': 0.000
#   'footsteps': 0.000
#   'maid': 0.002
#   'instant': 0.001
#   'mastery': 0.000
#   'day': 0.003
#   'end': 0.004
#   'get-up': 0.000
#   'slip': 0.000
#   'smouldering': 0.000
#   'watches': 0.000
#   'strange': 0.001
#   'papers': 0.003
#   'daily': 0.000
#   'sinister': 0.000
#   'socialists': 0.000
#   'deceased': 0.000
#   'vehmgericht': 0.000
#   'marchioness': 0.000
#   'darwinian': 0.000
#   'principles': 0.000
#   'ratcliff': 0.000
#   'government': 0.000
#   'standard': 0.000
#   'unsettling': 0.000
#   'minds': 0.000
#   'masses': 0.000
#   'consequent': 0.000
#   'boarding-house': 0.000
#   'avowed': 0.000
#   'liverpool': 0.000
#   'platform': 0.000
#   'whereabouts': 0.000
#   'crime': 0.003
#   'despotism': 0.000
#   'continental': 0.000
#   'effect': 0.001
#   'recollection': 0.000
#   'secretary': 0.001
#   'habits': 0.000
#   'discovery': 0.000
#   'acuteness': 0.000
#   'least': 0.001
#   'pattering': 0.000
#   'part': 0.001
#   'baker': 0.000
#   'dirtiest': 0.000
#   'youths': 0.000
#   'mere': 0.000
#   'fair-haired': 0.000
#   'tremendous': 0.000
#   'last': 0.005
#   'strain': 0.000
#   'mind': 0.000
#   'arm-chair': 0.000
#   'fun': 0.000
#   'wrong': 0.001
#   'babe': 0.000
#   'hat': 0.000
#   'feeling': 0.000
#   'mother': 0.000
#   'daughter': 0.001
#   'girl': 0.002
#   'continent': 0.000
#   'maid-servants': 0.000
#   'slack': 0.000
#   'navy': 0.000
#   'money': 0.001
#   'reason': 0.001
#   'wrist': 0.000
#   'confused': 0.000
#   'words': 0.002
#   'heavy': 0.001
#   'stick': 0.000
#   'pit': 0.000
#   'stomach': 0.000
#   'young': 0.004
#   'assurance': 0.000
#   'intention': 0.000
#   'centre': 0.002
#   'intelligence': 0.000
#   'opinion': 0.000
#   'one': 0.004
#   'third': 0.001
#   'hotels': 0.000
#   'vicinity': 0.000
#   'affirmative': 0.000
#   'boots': 0.000
#   'skirting': 0.000
#   'cause': 0.001
#   'flesh': 0.000
#   'deeds': 0.000
#   'field': 0.000
#   'dairy': 0.000
#   'lane': 0.000
#   'mews': 0.000
#   'windows': 0.001
#   'ladder': 0.000
#   'boy': 0.001
#   'basin': 0.000
#   'sheets': 0.000
#   'paying': 0.000
#   'motives': 0.000
#   'bed': 0.001
#   'window-sill': 0.000
#   'threads': 0.000
#   'purse': 0.000
#   'telegram': 0.000
#   'merest': 0.000
#   'dog': 0.001
#   'usual': 0.000
#   'rug': 0.000
#   'action': 0.000
#   'box': 0.001
#   'doctor': 0.002
#   'injured': 0.000
#   'mixture': 0.000
#   'wine': 0.000
#   'terrier': 0.000
#   'animal': 0.000
#   'cushion': 0.000
#   'unfortunate': 0.001
#   'perspiration': 0.000
#   'mists': 0.000
#   'inquiry': 0.000
#   'importance': 0.000
#   'good': 0.001
#   'logical': 0.000
#   'business': 0.001
#   'assassin': 0.000
#   'slightest': 0.000
#   'official': 0.001
#   'blame': 0.000
#   'depreciating': 0.000
#   'roots': 0.000
#   'spokesman': 0.000
#   'spring': 0.000
#   'jangling': 0.000
#   'glittering': 0.000
#   'prisoner': 0.001
#   'convulsive': 0.000
#   'saints': 0.000
#   'central': 0.001
#   'advance': 0.000
#   'sierra': 0.000
#   'yellowstone': 0.000
#   'north': 0.001
#   'colorado': 0.000
#   'south': 0.001
#   'saline': 0.000
#   'hardiest': 0.000
#   'braves': 0.000
#   'coyote': 0.000
#   'scrub': 0.000
#   'buzzard': 0.000
#   'clumsy': 0.000
#   'rocks': 0.000
#   'sole': 0.000
#   'wilderness': 0.000
#   'northern': 0.000
#   'eye': 0.000
#   'dwarfish': 0.000
#   'extreme': 0.000
#   'horizon': 0.000
#   'steel-blue': 0.000
#   'broad': 0.001
#   'desert': 0.000
#   'feet': 0.000
#   'wayside': 0.000
#   'fourth': 0.000
#   'region': 0.000
#   'projecting': 0.000
#   'hand': 0.001
#   'massive': 0.000
#   'ravine': 0.000
#   'distant': 0.000
#   'shelter': 0.000
#   'grey': 0.000
#   'child': 0.001
#   'towsy': 0.000
#   'cards': 0.000
#   'river': 0.001
#   'likes': 0.000
#   'fust': 0.000
#   'size': 0.000
#   'heaven': 0.000
#   'heads': 0.000
#   'vultures': 0.000
#   'west': 0.001
#   'forerunner': 0.000
#   'missouri': 0.000
#   'water': 0.001
#   'trees': 0.001
#   'waggon': 0.000
#   'plains': 0.000
#   'choruses': 0.000
#   'shawl': 0.000
#   'buzzards': 0.000
#   'reckless': 0.000
#   'cloudless': 0.000
#   'entreaty': 0.000
#   'prayer': 0.000
#   'shadow': 0.001
#   'boulder': 0.000
#   'eyelids': 0.000
#   'tired': 0.000
#   'head': 0.002
#   'breast': 0.000
#   'gold': 0.000
#   'wanderer': 0.000
#   'alkali': 0.000
#   'observer': 0.000
#   'prairie': 0.000
#   'whirl': 0.000
#   'canvas-covered': 0.000
#   'figures': 0.000
#   'haze': 0.000
#   'apparition': 0.000
#   'mountains': 0.001
#   'rear': 0.000
#   'enormous': 0.000
#   'straggling': 0.000
#   'waggons': 0.000
#   'white': 0.001
#   'clear': 0.000
#   'creaking': 0.000
#   'neighing': 0.000
#   'column': 0.000
#   'bluff': 0.000
#   'wells': 0.000
#   'rio': 0.000
#   'youngest': 0.000
#   'rugged': 0.000
#   'vanguard': 0.000
#   'elderly': 0.000
#   'pawnees': 0.000
#   'band': 0.000
#   'elder': 0.000
#   'precipitous': 0.000
#   'confidence': 0.000
#   'watchers': 0.000
#   'plain': 0.000
#   'skyline': 0.000
#   'alarm': 0.001
#   'barren': 0.000
#   'regular': 0.000
#   'ledge': 0.000
#   'new': 0.001
#   'cries': 0.000
#   'foul': 0.000
#   'skirt': 0.000
#   'wondering': 0.000
#   'rescuing': 0.000
#   'persecuted': 0.000
#   'chosen': 0.000
#   'angel': 0.000
#   'holy': 0.000
#   'violent': 0.000
#   'godless': 0.000
#   'mormons': 0.000
#   'person': 0.001
#   'hill': 0.000
#   'pilgrims': 0.000
#   'youth': 0.000
#   'strangers': 0.000
#   'destitution': 0.000
#   'gaudiness': 0.000
#   'others': 0.001
#   'crowd': 0.000
#   'episode': 0.000
#   'leader': 0.000
#   'far': 0.000
#   'voice': 0.000
#   'trials': 0.000
#   'immigrant': 0.000
#   'shores': 0.000
#   'mississippi': 0.000
#   'western': 0.000
#   'rocky': 0.000
#   'savage': 0.000
#   'accumulated': 0.000
#   'hearts': 0.000
#   'stoutest': 0.000
#   'sunlight': 0.000
#   'lips': 0.000
#   'promised': 0.000
#   'future': 0.001
#   'standing': 0.000
#   'tradesman': 0.000
#   'artisan': 0.000
#   'town': 0.001
#   'wheat': 0.000
#   'closing': 0.000
#   'twilight': 0.000
#   'clatter': 0.000
#   'hammer': 0.000
#   'rasp': 0.000
#   'saw': 0.000
#   'monument': 0.000
#   'immigrants': 0.000
#   'mormon': 0.000
#   'elasticity': 0.000
#   'shock': 0.000
#   'esteem': 0.000
#   'settlers': 0.000
#   'exception': 0.000
#   'farm': 0.000
#   'susceptibilities': 0.000
#   'manner': 0.000
#   'atlantic': 0.000
#   'religion': 0.000
#   'log-house': 0.000
#   'keen': 0.000
#   'balsamic': 0.000
#   'pine': 0.000
#   'high': 0.001
#   'wheatfields': 0.000
#   'ease': 0.000
#   'bud': 0.000
#   'richest': 0.000
#   'farmers': 0.000
#   'father': 0.000
#   'maiden': 0.000
#   'tone': 0.000
#   'touch': 0.000
#   'dawn': 0.000
#   'occasion': 0.000
#   'bees': 0.000
#   'fields': 0.000
#   'streets': 0.000
#   'dusty': 0.000
#   'overland': 0.000
#   'elect': 0.000
#   'outlying': 0.000
#   'skill': 0.000
#   'exercise': 0.000
#   'fearlessness': 0.000
#   'travel-stained': 0.000
#   'unemotional': 0.000
#   'beauty': 0.000
#   'pale-faced': 0.000
#   'outskirts': 0.000
#   'beasts': 0.000
#   'moving': 0.000
#   'hopes': 0.000
#   'cavalcade': 0.000
#   'horns': 0.000
#   'creatures': 0.000
#   'flank': 0.000
#   'mustang': 0.000
#   'excited': 0.000
#   'saddle': 0.000
#   'hoofs': 0.000
#   'unwieldy': 0.000
#   'bridle': 0.000
#   'rising': 0.000
#   'steam': 0.000
#   'struggling': 0.000
#   'frightened': 0.000
#   'drove': 0.000
#   'rough': 0.000
#   'jefferson': 0.000
#   'suggestion': 0.000
#   'nevada': 0.000
#   'fair': 0.000
#   'love': 0.000
#   'wild': 0.000
#   'farm-house': 0.000
#   'news': 0.001
#   'outside': 0.001
#   'fence': 0.000
#   'longer': 0.000
#   'harder': 0.000
#   'caã±on': 0.000
#   'happiest': 0.000
#   'impending': 0.000
#   'arrangement': 0.000
#   'land': 0.000
#   'victims': 0.000
#   'inquisition': 0.000
#   'secret': 0.001
#   'church': 0.000
#   'doubts': 0.000
#   'recalcitrants': 0.000
#   'supply': 0.000
#   'harems': 0.000
#   'elders': 0.000
#   'traces': 0.000
#   'lonely': 0.000
#   'danite': 0.000
#   'organization': 0.000
#   'horror': 0.000
#   'names': 0.000
#   'participators': 0.000
#   'things': 0.000
#   'click': 0.000
#   'farmer': 0.000
#   'true': 0.001
#   'temple': 0.000
#   'gossip': 0.000
#   'thirteenth': 0.000
#   'code': 0.000
#   'sainted': 0.000
#   'sacred': 0.000
#   'orders': 0.000
#   'shingly': 0.000
#   'hole': 0.000
#   'fastening': 0.000
#   'doors': 0.000
#   'rusty': 0.000
#   'imminent': 0.000
#   'posts': 0.000
#   'rocking-chair': 0.000
#   'stove': 0.000
#   'son': 0.001
#   'nations': 0.000
#   'advice': 0.000
#   'stronger': 0.000
#   'richer': 0.000
#   'backs': 0.000
#   'council': 0.000
#   'smiting': 0.000
#   'arm': 0.000
#   'wife': 0.001
#   'sooner': 0.000
#   'aid': 0.000
#   'sturdy': 0.000
#   'settlement': 0.000
#   'authority': 0.000
#   'fate': 0.000
#   'vague': 0.000
#   'coverlet': 0.000
#   'dash': 0.000
#   'incident': 0.001
#   'twenty-nine': 0.000
#   'balance': 0.000
#   'month': 0.000
#   'ceiling': 0.001
#   'floors': 0.000
#   'troubled': 0.000
#   'arrival': 0.000
#   'absentee': 0.000
#   'more-frequented': 0.000
#   'blow': 0.001
#   'figure': 0.000
#   'allotted': 0.000
#   'invisible': 0.000
#   'silence': 0.001
#   'quiet': 0.000
#   'panels': 0.000
#   'suspense': 0.000
#   'bolt': 0.000
#   'stars': 0.000
#   'prostrate': 0.000
#   'rapidity': 0.000
#   'astonished': 0.000
#   'fierce': 0.000
#   'cold': 0.001
#   'danger': 0.001
#   'eagle': 0.000
#   'servants': 0.001
#   'approaching': 0.000
#   'eatables': 0.000
#   'mountain': 0.000
#   'greeting': 0.000
#   'lovers': 0.000
#   'greatness': 0.000
#   'peril': 0.000
#   'side': 0.002
#   'horses': 0.000
#   'revolver': 0.000
#   'lights': 0.000
#   'darkened': 0.000
#   'sacrifice': 0.000
#   'honour': 0.000
#   'rustling': 0.000
#   'spirit': 0.000
#   'bag': 0.000
#   'scanty': 0.000
#   'hedge': 0.000
#   'gap': 0.000
#   'cornfields': 0.000
#   'ears': 0.000
#   'plaintive': 0.000
#   'obscurity': 0.000
#   'whip-poor-will': 0.000
#   'hunter': 0.000
#   'defile': 0.000
#   'faithful': 0.000
#   'mule': 0.000
#   'ribs': 0.000
#   'irregular': 0.000
#   'fugitives': 0.000
#   'terrible': 0.001
#   'jurisdiction': 0.000
#   'pass': 0.000
#   'track': 0.001
#   'silent': 0.000
#   'rifle': 0.000
#   'sentinel': 0.000
#   'countersign': 0.000
#   'larch': 0.000
#   'fear': 0.000
#   'echoes': 0.000
#   'weary': 0.000
#   'eastern': 0.000
#   'caps': 0.000
#   'magnificent': 0.000
#   'defiles': 0.000
#   'chill': 0.000
#   'reach': 0.000
#   'middle': 0.001
#   'needs': 0.000
#   'blazing': 0.000
#   'back-ground': 0.000
#   'intervening': 0.000
#   'bark': 0.000
#   'edge': 0.001
#   'big-horn': 0.000
#   'trigger': 0.000
#   'precipice': 0.000
#   'creature': 0.001
#   'difficulty': 0.000
#   'ravines': 0.000
#   'mouth': 0.000
#   'cliffs': 0.000
#   'gladness': 0.000
#   'glen': 0.000
#   'dreary': 0.000
#   'friends': 0.000
#   'precious': 0.000
#   'remains': 0.000
#   'camp': 0.000
#   'cleft': 0.000
#   'inscription': 0.000
#   'harem': 0.000
#   'certainty': 0.000
#   'lethargy': 0.000
#   'indians': 0.000
#   'desolate': 0.000
#   'food': 0.000
#   'sixth': 0.000
#   'home': 0.000
#   'spruce': 0.000
#   'ferriers': 0.000
#   'stone': 0.001
#   'endowment': 0.000
#   'party': 0.000
#   'gorge': 0.000
#   'haunts': 0.000
#   'prediction': 0.000
#   'hateful': 0.000
#   'sake': 0.000
#   'burial': 0.000
#   'bier': 0.000
#   'early': 0.001
#   'cowering': 0.000
#   'pure': 0.000
#   'wedding-ring': 0.000
#   'undeniable': 0.000
#   'circlet': 0.000
#   'weird': 0.000
#   'suburbs': 0.000
#   'precaution': 0.000
#   'predominant': 0.000
#   'incessant': 0.000
#   'mines': 0.000
#   'younger': 0.000
#   'secession': 0.000
#   'malcontents': 0.000
#   'small': 0.001
#   'united': 0.000
#   'men': 0.001
#   'vagrant': 0.000
#   'peace': 0.000
#   'jealousy': 0.000
#   'avenger': 0.000
#   'pursuit': 0.000
#   'danish': 0.000
#   'scuffle': 0.000
#   'police-station': 0.000
#   'towel': 0.000
#   'magistrates': 0.000
#   'week': 0.000
#   'mean': 0.000
#   'inspector': 0.004
#   'salt': 0.000
#   'advisability': 0.000
#   'interests': 0.000
#   'tussle': 0.000
#   'brink': 0.000
#   'absolute': 0.000
#   'events': 0.000
#   'accuracy': 0.000
#   'subjoined': 0.000
#   'lapse': 0.000
#   'marriage': 0.000
#   'owner': 0.000
#   'hardest': 0.000
#   'mazes': 0.000
#   'ghost': 0.000
#   'hour': 0.001
#   'guard': 0.000
#   'bustle': 0.000
#   'offender': 0.000
#   'opportunity': 0.000
#   'interval': 0.000
#   'difficult': 0.000
#   'nose': 0.000
#   'terrace': 0.000
#   'talking': 0.000
#   'collar': 0.000
#   'steps': 0.001
#   'cur': 0.000
#   'craze': 0.000
#   'game': 0.001
#   'many': 0.000
#   'professor': 0.002
#   'bottle': 0.000
#   'poison': 0.000
#   'pill': 0.000
#   'dripping': 0.000
#   'contentment': 0.000
#   'pulses': 0.000
#   'look': 0.000
#   'alkaloid': 0.000
#   'londoners': 0.000
#   'pocket': 0.000
#   'arms': 0.000
#   'life': 0.000
#   'poisoned': 0.000
#   'chance': 0.001
#   'yard': 0.001
#   'bracelets': 0.000
#   'professional': 0.000
#   'scratching': 0.000
#   'finishing': 0.000
#   'forms': 0.000
#   'thursday': 0.000
#   'aneurism': 0.000
#   'cell': 0.000
#   'investigation': 0.000
#   'proof': 0.000
#   'criminal': 0.001
#   'grand': 0.000
#   'every-day': 0.000
#   'different': 0.000
#   'wheels': 0.000
#   'ordinary': 0.000
#   'art': 0.000
#   'constables': 0.000
#   'nocturnal': 0.000
#   'tall': 0.000
#   'agitated': 0.000
#   'hatred': 0.000
#   'method': 0.000
#   'forcible': 0.000
#   'cases': 0.000
#   'contrary': 0.001
#   'perpetrator': 0.000
#   'negative': 0.000
#   'additional': 0.000
#   'answer': 0.000
#   'protection': 0.000
#   'irresistible': 0.000
#   'jarveys': 0.000
#   'pills': 0.000
#   'existence': 0.000
#   'echo': 0.000
#   'paragraph': 0.000
#   'public': 0.001
#   'efficiency': 0.000
#   'well-known': 0.000
#   'consciousness': 0.000
#   'roman': 0.000
#   'statement': 0.000
#   'story': 0.001
#   'bald-headed': 0.000
#   'barrel': 0.000
#   'chain': 0.000
#   'islander': 0.000
#   'delicate': 0.000
#   'sinewy': 0.000
#   'tiny': 0.000
#   'velvet-lined': 0.000
#   'courage': 0.000
#   'cool': 0.000
#   'experience': 0.000
#   'beaune': 0.000
#   'afghan': 0.000
#   'cost': 0.000
#   'loss': 0.001
#   'data': 0.000
#   'work': 0.001
#   'pleasure': 0.000
#   'somewhat': 0.000
#   'romance': 0.000
#   'curious': 0.001
#   'egotism': 0.000
#   'years': 0.000
#   'french': 0.001
#   'celtic': 0.000
#   'wide': 0.000
#   'higher': 0.000
#   'ardent': 0.000
#   'frenchman': 0.000
#   'ideal': 0.000
#   'distinction': 0.000
#   'ashes': 0.000
#   'trained': 0.000
#   'black': 0.001
#   'tracing': 0.000
#   'uses': 0.000
#   'influence': 0.000
#   'form': 0.000
#   'scientific': 0.000
#   'antecedents': 0.000
#   'wigmore': 0.000
#   'limits': 0.000
#   'seymour': 0.000
#   'neighborhood': 0.000
#   'post-office': 0.000
#   'simplest': 0.000
#   'impress': 0.000
#   'kindness': 0.000
#   'character': 0.000
#   'late': 0.001
#   'watch': 0.000
#   'test': 0.000
#   'dial': 0.000
#   'works': 0.000
#   'h.': 0.000
#   'w.': 0.000
#   'date': 0.001
#   'initials': 0.000
#   'eldest': 0.000
#   'habit': 0.001
#   'ticket': 0.000
#   'pledge': 0.000
#   'inner': 0.001
#   'key-hole': 0.000
#   'thousands': 0.000
#   'injustice': 0.000
#   'cocaine': 0.000
#   'duncolored': 0.000
#   'brass': 0.000
#   'dress': 0.000
#   'seat': 0.000
#   'langham': 0.000
#   'manager': 0.001
#   'sentence': 0.000
#   '3d': 0.000
#   'andaman': 0.000
#   'officers': 0.000
#   'convict-guard': 0.000
#   '34th': 0.000
#   'major': 0.000
#   'times': 0.000
#   'family': 0.001
#   'capacity': 0.000
#   'advertisement': 0.000
#   'post': 0.000
#   'sender': 0.000
#   'envelope': 0.001
#   'lyceum': 0.000
#   'pearl-box': 0.000
#   'authorship': 0.000
#   'irrepressible': 0.000
#   'twirl': 0.000
#   'gray': 0.000
#   'sombre': 0.000
#   'emotional': 0.000
#   'london': 0.001
#   'rule': 0.000
#   'volume': 0.000
#   'daring': 0.000
#   'deep': 0.000
#   'blackest': 0.000
#   'cup': 0.000
#   '28th': 0.000
#   'presents': 0.000
#   'few': 0.000
#   'troops': 0.000
#   'diagram': 0.000
#   'left-hand': 0.000
#   'muddy': 0.000
#   'lamps': 0.000
#   'slimy': 0.000
#   'shop-windows': 0.000
#   'steamy': 0.000
#   'endless': 0.000
#   'gloom': 0.001
#   'crowds': 0.000
#   'side-entrances': 0.000
#   'parties': 0.000
#   'foggy': 0.000
#   'fog': 0.001
#   'vauxhall': 0.000
#   'surrey': 0.000
#   'bridge': 0.001
#   'thames': 0.000
#   'coarse': 0.000
#   'monster': 0.000
#   'giant': 0.000
#   'commonplace': 0.000
#   'sahib': 0.000
#   'indian': 0.000
#   'glare': 0.000
#   'howling': 0.000
#   'carpet': 0.001
#   'foot': 0.000
#   'fashion': 0.000
#   'aortic': 0.000
#   'mitral': 0.000
#   'mild': 0.000
#   'smoke': 0.000
#   'rose-water': 0.000
#   'liberty': 0.000
#   'arts': 0.000
#   'landscape': 0.000
#   'bouguereau': 0.000
#   'modern': 0.000
#   'interview': 0.000
#   'sensation': 0.000
#   'breakfast-table': 0.000
#   'cursed': 0.000
#   'treasure': 0.001
#   'quinine-bottle': 0.000
#   'design': 0.000
#   'agra': 0.000
#   'chaplet': 0.000
#   'division': 0.000
#   'treasure-chest': 0.000
#   'gash': 0.000
#   'wiser': 0.000
#   'whitening': 0.000
#   'intruder': 0.000
#   'flower-bed': 0.000
#   'phrase': 0.000
#   'short': 0.000
#   'side-table': 0.000
#   'lids': 0.000
#   'commonplaceness': 0.000
#   'puffs': 0.000
#   'hiding-place': 0.000
#   'splendor': 0.000
#   'pearls': 0.000
#   'view': 0.000
#   'tube': 0.000
#   'rattle': 0.000
#   'cubic': 0.000
#   'building': 0.001
#   'heights': 0.000
#   'separate': 0.000
#   'space': 0.000
#   'total': 0.000
#   'lath-and-plaster': 0.000
#   'value': 0.000
#   'jewels': 0.000
#   'mention': 0.000
#   'soul': 0.000
#   'babble': 0.000
#   'answers': 0.000
#   'coachman': 0.000
#   'damp': 0.000
#   'westward': 0.000
#   'rifts': 0.000
#   'side-lamps': 0.000
#   'carriage': 0.002
#   'opening': 0.000
#   'lantern': 0.000
#   'master': 0.001
#   'porter': 0.000
#   'amateur': 0.000
#   'prize-fighter': 0.000
#   'jaw': 0.000
#   'vast': 0.000
#   'premises': 0.000
#   'favorite': 0.000
#   'moonshine': 0.000
#   'housekeeper': 0.001
#   'circles': 0.000
#   'saddest': 0.000
#   'shrill': 0.000
#   'grounds': 0.001
#   'instinct': 0.000
#   'moles': 0.000
#   'prospectors': 0.000
#   'treasure-seekers': 0.000
#   'helpless': 0.000
#   'color': 0.000
#   'lamp': 0.002
#   'cocoa-nut': 0.000
#   'corridor': 0.001
#   'handle': 0.000
#   'breath': 0.000
#   'features': 0.000
#   'nerves': 0.000
#   'lock': 0.001
#   'corners': 0.000
#   'midst': 0.000
#   'eyebrows': 0.000
#   'skin': 0.000
#   'ear': 0.000
#   'puncture': 0.000
#   'chamber': 0.000
#   'door-way': 0.000
#   'print': 0.000
#   'sill': 0.000
#   'round': 0.000
#   'boot-mark': 0.000
#   'mark': 0.001
#   'timber-toe': 0.000
#   'wooden-legged': 0.000
#   'open': 0.001
#   'brick-work': 0.000
#   'rope': 0.001
#   'hook': 0.000
#   'ally': 0.000
#   'regions': 0.000
#   'annals': 0.000
#   'chimney': 0.000
#   'grate': 0.000
#   'impossible': 0.000
#   'roof': 0.001
#   'garret': 0.000
#   'rafters': 0.000
#   'sloping': 0.000
#   'prints': 0.000
#   'horrid': 0.000
#   'planks': 0.000
#   'misfortune': 0.000
#   'creosote': 0.000
#   'carboy': 0.000
#   'stuff': 0.000
#   '--': 0.000
#   'accredited': 0.000
#   'clamor': 0.000
#   'muscles': 0.000
#   'drawn': 0.000
#   'means': 0.000
#   'system': 0.000
#   'scalp': 0.000
#   'thorn': 0.000
#   'blunt': 0.000
#   'regulars': 0.000
#   'auxiliary': 0.000
#   'still': 0.000
#   'theorist': 0.000
#   'bishopgate': 0.000
#   'message': 0.001
#   'nail': 0.000
#   'brother': 0.000
#   'net': 0.000
#   'fat': 0.000
#   'card': 0.000
#   'trap-door': 0.000
#   'queen': 0.000
#   'poor': 0.001
#   'charge': 0.000
#   'heel': 0.000
#   'less': 0.001
#   'precision': 0.000
#   'pair': 0.000
#   'original': 0.001
#   'right-hand': 0.000
#   'angelic': 0.000
#   'struggle': 0.000
#   'effort': 0.000
#   'conventionalities': 0.000
#   'step': 0.000
#   'half-opened': 0.000
#   'barometer': 0.000
#   'bright': 0.000
#   'wilder': 0.000
#   'sending': 0.000
#   'rediscovery': 0.000
#   'discoverer': 0.000
#   'remarkable': 0.000
#   'blind': 0.001
#   'upper': 0.001
#   'kennels': 0.000
#   'wiper': 0.000
#   'badger': 0.000
#   'bars': 0.000
#   'run': 0.000
#   'bettles': 0.000
#   'children': 0.000
#   'queer': 0.000
#   'uncertain': 0.000
#   'palace': 0.000
#   'ex-prize-fighter': 0.000
#   'door-step': 0.000
#   'gatekeeper': 0.000
#   'creasote': 0.000
#   'chief': 0.001
#   'wood-work': 0.000
#   'ridge': 0.000
#   'water-pipe': 0.000
#   'chances': 0.000
#   'bouquet': 0.000
#   'handkerchief': 0.000
#   'mongrel': 0.000
#   'water-barrel': 0.000
#   'trail': 0.000
#   'east': 0.000
#   'trenches': 0.000
#   'boundary': 0.000
#   'crevices': 0.000
#   'slight': 0.000
#   'pungent': 0.000
#   'readiest': 0.000
#   'pretty': 0.000
#   'chart': 0.000
#   'sequel': 0.000
#   'possession': 0.000
#   'double': 0.000
#   'gauntlet': 0.000
#   'guards': 0.000
#   'efforts': 0.000
#   'household': 0.000
#   'lofty': 0.000
#   'associate': 0.000
#   'stamped': 0.000
#   'treasure-box': 0.000
#   'andamans': 0.000
#   'brook': 0.000
#   'parent': 0.000
#   'chambers': 0.000
#   'guidance': 0.000
#   'half-rural': 0.000
#   'square-topped': 0.000
#   'side-streets': 0.000
#   'oval': 0.000
#   'gleam': 0.000
#   'side-gate': 0.000
#   'enclosure': 0.000
#   'sawyers': 0.000
#   'hand-trolley': 0.000
#   'cask': 0.000
#   'staves': 0.000
#   'trolley': 0.000
#   'timber-yard': 0.000
#   'seasoning': 0.000
#   'creasote-barrel': 0.000
#   'river-side': 0.000
#   'wharf': 0.000
#   'rude': 0.000
#   'jetty': 0.000
#   'prodigy': 0.000
#   'barge': 0.000
#   'prices': 0.000
#   'launch': 0.000
#   'winder': 0.000
#   'wooden': 0.000
#   'stones': 0.000
#   'aurora': 0.000
#   'beam': 0.000
#   'sides': 0.000
#   'wherry': 0.000
#   'stream': 0.000
#   'chase': 0.000
#   'runaways': 0.000
#   'successive': 0.000
#   'criminals': 0.000
#   'breakfast': 0.000
#   'coffee': 0.000
#   'energetic': 0.000
#   'ubiquitous': 0.000
#   'gratifying': 0.000
#   'thief': 0.000
#   'miscreants': 0.000
#   'prompt': 0.000
#   'unofficial': 0.000
#   'instructions': 0.000
#   'boat': 0.000
#   'broken': 0.000
#   'associates': 0.000
#   'footmarks': 0.000
#   'inhabitants': 0.000
#   'hindoo': 0.000
#   'sandal-wearing': 0.000
#   'thong': 0.000
#   'shelf': 0.000
#   'bay': 0.000
#   'bushmen': 0.000
#   'digger': 0.000
#   'terra': 0.000
#   'average': 0.000
#   'survivors': 0.000
#   'rise': 0.000
#   'sweet': 0.000
#   'twinkle': 0.000
#   'exact': 0.001
#   'conventional': 0.000
#   'rescue': 0.000
#   'issue': 0.000
#   'prospect': 0.000
#   'blinds': 0.000
#   'stairhead': 0.000
#   'craft': 0.000
#   'ladies': 0.000
#   'clinking': 0.000
#   'real': 0.001
#   'fresh': 0.000
#   'agony': 0.000
#   'sum': 0.000
#   'said': 0.000
#   'ill-assorted': 0.000
#   'keenest': 0.000
#   'over-refinement': 0.000
#   'reasons': 0.000
#   'brusque': 0.000
#   'sholto': 0.000
#   'finish': 0.000
#   'climb': 0.000
#   'sounds': 0.000
#   'slow': 0.000
#   'petulant': 0.000
#   'uselessness': 0.000
#   'proper': 0.000
#   'war-path': 0.000
#   'westminster': 0.000
#   'authorities': 0.000
#   'detail': 0.000
#   'buddhism': 0.000
#   'war-ships': 0.000
#   'reaction': 0.000
#   'preceding': 0.000
#   'cloth': 0.000
#   'success': 0.000
#   'ropes': 0.000
#   'stern': 0.000
#   'rudder': 0.000
#   'engines': 0.000
#   'tower': 0.000
#   'hydrocarbon': 0.000
#   'sholtos': 0.000
#   'peculiar': 0.000
#   'downs': 0.000
#   'colonies': 0.000
#   'yards': 0.000
#   'sixteenth': 0.000
#   'foreman': 0.000
#   'cross': 0.000
#   'summit': 0.000
#   'shore': 0.000
#   'policemen': 0.000
#   'entrance': 0.000
#   'folk': 0.000
#   'gaslight': 0.000
#   'individual': 0.000
#   'aggregate': 0.000
#   'statistician': 0.000
#   'heels': 0.000
#   'yard-entrance': 0.000
#   'furnaces': 0.000
#   'powerful': 0.000
#   'river-water': 0.000
#   'swirl': 0.000
#   'pace': 0.000
#   'engine-room': 0.000
#   'murky': 0.000
#   'frail': 0.000
#   'pool': 0.000
#   'isle': 0.000
#   'dainty': 0.000
#   'tiller': 0.000
#   'furnace': 0.000
#   'waist': 0.000
#   'panting': 0.000
#   'deck': 0.000
#   'thigh': 0.000
#   'huddled': 0.000
#   'unhallowed': 0.000
#   'waters': 0.000
#   'southern': 0.000
#   'bank': 0.000
#   'mud-bank': 0.000
#   'fugitive': 0.000
#   'sodden': 0.000
#   'mud': 0.000
#   'deeper': 0.000
#   'sticky': 0.000
#   'ill-omened': 0.000
#   'bones': 0.000
#   'horrible': 0.000
#   'cabin': 0.000
#   'iron': 0.000
#   'job': 0.000
#   'simple': 0.000
#   'merchant': 0.000
#   'fastest': 0.000
#   'esmeralda': 0.000
#   'brazils': 0.000
#   'consequential': 0.000
#   'strength': 0.000
#   'capture': 0.000
#   'speech': 0.000
#   'drawing-room': 0.000
#   'obliging': 0.000
#   'neck': 0.000
#   'soft': 0.000
#   'basket': 0.000
#   'rich': 0.000
#   'chair': 0.001
#   'will': 0.000
#   'dart': 0.000
#   'image': 0.000
#   'poker': 0.000
#   'hasp': 0.000
#   'lid': 0.000
#   'iron-work': 0.000
#   'reward': 0.000
#   'loot': 0.000
#   'ex-convict': 0.000
#   'justice': 0.000
#   'mangrove-tree': 0.000
#   'filthy': 0.000
#   'handcuffs': 0.000
#   'impassioned': 0.000
#   'fury': 0.000
#   'passion': 0.000
#   'country-side': 0.000
#   'goose-step': 0.000
#   'ganges': 0.000
#   'service': 0.000
#   'knee': 0.000
#   'accident': 0.000
#   'colonel': 0.002
#   'plantation': 0.000
#   'idlers': 0.000
#   'pay': 0.000
#   'border': 0.000
#   'northwest': 0.000
#   'burning': 0.000
#   'book-work': 0.000
#   'managing': 0.000
#   'crash': 0.000
#   'flames': 0.000
#   'paddy-fields': 0.000
#   'english': 0.000
#   'millions': 0.000
#   'hundreds': 0.000
#   'cruellest': 0.000
#   'rebels': 0.000
#   'map': 0.000
#   'compass': 0.000
#   'queerest': 0.000
#   'scorpions': 0.000
#   'centipedes': 0.000
#   'angles': 0.000
#   'guns': 0.000
#   'innumerable': 0.000
#   'fort': 0.000
#   'southwest': 0.000
#   'gate-way': 0.000
#   'twinkling': 0.000
#   'beating': 0.000
#   'yells': 0.000
#   'officer': 0.000
#   'rounds': 0.000
#   'weariness': 0.000
#   'match': 0.000
#   'sepoys': 0.000
#   'knife': 0.000
#   'taller': 0.000
#   'christians': 0.000
#   'ditch': 0.000
#   'rebel': 0.000
#   'safety': 0.000
#   'naked': 0.000
#   'threefold': 0.000
#   'honor': 0.000
#   'tale': 0.000
#   'sikh': 0.000
#   'englishman': 0.000
#   'troubles': 0.000
#   'tiger': 0.000
#   'sepoy': 0.000
#   'vaults': 0.000
#   'choicest': 0.000
#   'guise': 0.000
#   'due': 0.000
#   'rajah': 0.000
#   'talk': 0.000
#   'commandant': 0.000
#   'taking': 0.000
#   'purpose': 0.000
#   'moat': 0.000
#   'mound-heaps': 0.000
#   'mire': 0.000
#   'ague': 0.000
#   'chills': 0.000
#   'unhappy': 0.000
#   'friend': 0.000
#   'bundle': 0.000
#   'measured': 0.000
#   'loud': 0.000
#   'wind': 0.001
#   'fall': 0.000
#   'whiskey-and-water': 0.000
#   'sikhs': 0.000
#   'brick': 0.000
#   'chest': 0.000
#   'best-preserved': 0.000
#   'frontier': 0.000
#   'pandies': 0.000
#   'plunder': 0.000
#   'murderers': 0.000
#   'spy': 0.000
#   'leg': 0.000
#   'kick': 0.000
#   'cuff': 0.000
#   'slopes': 0.000
#   'surgeon': 0.000
#   'lookout': 0.000
#   'surgery': 0.000
#   'native': 0.000
#   'soldiers': 0.000
#   'civilians': 0.000
#   'poorer': 0.000
#   'luck': 0.000
#   'beach': 0.000
#   'information': 0.000
#   'governor-general': 0.000
#   'places': 0.000
#   'twitch': 0.000
#   'voyage': 0.000
#   'monthly': 0.000
#   'consent': 0.000
#   'villain': 0.000
#   'mail-boats': 0.000
#   'scoundrel': 0.000
#   'conditions': 0.000
#   'gallows': 0.000
#   'slaying': 0.000
#   'woods': 0.000
#   'fonder': 0.000
#   'island': 0.000
#   'split': 0.000
#   'wood': 0.000
#   'eleventh': 0.000
#   'speed': 0.000
#   'convict': 0.000
#   'wary': 0.000
#   'ordeal': 0.000
#   'makings': 0.000
#   'butler': 0.001
#   'undivided': 0.000
#   'cocaine-bottle': 0.000
#   'softer': 0.000
#   'veil': 0.000
#   'home-centred': 0.000
#   'drowsiness': 0.000
#   'drug': 0.000
#   'study': 0.001
#   'trepoff': 0.000
#   'singular': 0.001
#   'atkinson': 0.000
#   'mission': 0.000
#   'reigning': 0.000
#   'readers': 0.000
#   'twentieth': 0.000
#   'well-remembered': 0.000
#   'firelight': 0.000
#   'leather': 0.000
#   'edges': 0.000
#   'medical': 0.000
#   'royal': 0.000
#   'texture': 0.000
#   'maker': 0.000
#   "'": 0.000
#   "'eg": 0.000
#   'sleeves': 0.000
#   'tops': 0.000
#   'cheekbones': 0.000
#   'count': 0.001
#   'august': 0.000
#   'title': 0.000
#   'languid': 0.000
#   'mask': 0.000
#   'king': 0.001
#   'acquaintance': 0.000
#   'deep-sea': 0.000
#   'photograph': 0.001
#   'strict': 0.000
#   'betrothal': 0.000
#   'provinces': 0.000
#   'grim': 0.000
#   'exalted': 0.000
#   'quick': 0.000
#   'bedroom': 0.001
#   'coach-house': 0.000
#   'ostlers': 0.000
#   'neighbourhood': 0.001
#   'daintiest': 0.000
#   'serpentine-mews': 0.000
#   'advantages': 0.000
#   'relation': 0.000
#   'edgeware': 0.000
#   'tags': 0.000
#   'buckles': 0.000
#   'landau': 0.000
#   'altar': 0.000
#   'secure': 0.000
#   'lady': 0.005
#   'clergyman': 0.000
#   'bridegroom': 0.000
#   'bride': 0.000
#   'park': 0.000
#   'tray': 0.000
#   'cry': 0.000
#   'signal': 0.000
#   'stage': 0.000
#   'coming': 0.000
#   'locality': 0.000
#   'rumble': 0.000
#   'side-lights': 0.000
#   'curve': 0.000
#   'avenue': 0.000
#   'loafing': 0.000
#   'scissors-grinder': 0.000
#   'guardsmen': 0.000
#   'couch': 0.000
#   'beautiful': 0.000
#   'grace': 0.000
#   'smoke-rocket': 0.000
#   'shouting': 0.000
#   'row': 0.000
#   'darlington': 0.000
#   'arnsworth': 0.000
#   'rocket': 0.000
#   'dimly': 0.000
#   'brougham': 0.000
#   '5.15': 0.000
#   'furniture': 0.000
#   'bell-pull': 0.000
#   'freedom': 0.000
#   'celebrated': 0.000
#   'nest': 0.000
#   'kingdom': 0.000
#   'cleverness': 0.000
#   'honourable': 0.000
#   'autumn': 0.000
#   'stout': 0.000
#   'settee': 0.000
#   'conventions': 0.000
#   'enthusiasm': 0.000
#   'smaller': 0.000
#   'portly': 0.000
#   'indications': 0.000
#   'expression': 0.000
#   'obvious': 0.000
#   'snuff': 0.000
#   'freemasonry': 0.000
#   'smooth': 0.000
#   'elbow': 0.000
#   'desk': 0.000
#   'fish': 0.000
#   'literature': 0.000
#   'fishes': 0.000
#   'bequest': 0.000
#   'league': 0.000
#   'age': 0.000
#   'offices': 0.000
#   'extraordinary': 0.000
#   'beaten': 0.000
#   'full': 0.000
#   'cellar': 0.000
#   'trustees': 0.000
#   'door-mat': 0.000
#   'vacancies': 0.000
#   'interest': 0.000
#   'providing': 0.000
#   'shutters': 0.000
#   'pain': 0.000
#   'vacancy': 0.000
#   'pensioners': 0.000
#   'fund': 0.000
#   'propagation': 0.000
#   'red-heads': 0.000
#   'hours': 0.000
#   'mornings': 0.000
#   'important': 0.000
#   "'encyclopaedia": 0.000
#   'amount': 0.000
#   'billet': 0.000
#   'b': 0.000
#   'panel': 0.000
#   'rueful': 0.000
#   'comical': 0.000
#   'landlord': 0.000
#   'ground-floor': 0.000
#   'minute': 0.000
#   'bill': 0.000
#   'gesture': 0.000
#   'st.': 0.000
#   'programme': 0.000
#   'houses': 0.000
#   'pawnbroker': 0.000
#   'assistant': 0.000
#   'knees': 0.000
#   'parts': 0.000
#   'traffic': 0.000
#   'immense': 0.000
#   'footpaths': 0.000
#   'hurrying': 0.000
#   'faded': 0.000
#   'order': 0.000
#   'tobacconist': 0.000
#   'coburg': 0.000
#   'vegetarian': 0.000
#   'stalls': 0.000
#   'sleuth-hound': 0.000
#   'relentless': 0.000
#   'dual': 0.000
#   'poetic': 0.000
#   'swing': 0.000
#   'lust': 0.000
#   'visit': 0.000
#   'ominous': 0.000
#   'hint': 0.000
#   'rack': 0.000
#   'running': 0.000
#   'play': 0.000
#   'stake': 0.000
#   'tunes': 0.000
#   'flags': 0.000
#   'goodness': 0.000
#   'solemn': 0.000
#   'cracks': 0.000
#   'chairman': 0.000
#   'director': 0.000
#   'crate': 0.000
#   'directors': 0.000
#   'screen': 0.000
#   'slide': 0.000
#   'vault': 0.000
#   'holes': 0.000
#   'gentle': 0.000
#   'bulky': 0.000
#   'thin': 0.000
#   'aperture': 0.000
#   'chisel': 0.000
#   'bags': 0.000
#   'derbies': 0.000
#   'custody': 0.000
#   'copying': 0.000
#   'colour': 0.000
#   'â£4': 0.000
#   'temporary': 0.000
#   'motive': 0.000
#   'coolest': 0.000
#   'bullion': 0.000
#   'commonplaces': 0.000
#   'race': 0.000
#   'roofs': 0.000
#   'plannings': 0.000
#   'cross-purposes': 0.000
#   'wonderful': 0.000
#   'platitudes': 0.000
#   'magistrate': 0.000
#   'vital': 0.000
#   'push': 0.000
#   'bruise': 0.000
#   'sympathetic': 0.000
#   'crudest': 0.000
#   'dundas': 0.000
#   'husband': 0.000
#   'conduct': 0.000
#   'irene': 0.000
#   'observation': 0.000
#   'charm': 0.000
#   'simpler': 0.000
#   'bigger': 0.000
#   'parted': 0.000
#   'swimmer': 0.000
#   'easy': 0.000
#   'letters': 0.000
#   'machine': 0.000
#   'tottenham': 0.000
#   'goodwill': 0.000
#   'gasfitters': 0.000
#   'drawer': 0.000
#   'firm': 0.000
#   'ball': 0.000
#   'leadenhall': 0.000
#   'daylight': 0.000
#   'quinsy': 0.000
#   'testament': 0.000
#   'sly': 0.000
#   'wedding': 0.001
#   'friday': 0.000
#   'st': 0.000
#   'four-wheeler': 0.000
#   'weight': 0.000
#   'preposterous': 0.000
#   'vacuous': 0.000
#   'hague': 0.000
#   'suggestiveness': 0.000
#   'trouser': 0.000
#   'typewritist': 0.000
#   'sewing-machine': 0.000
#   'thumb': 0.000
#   'broadest': 0.000
#   'dint': 0.000
#   'forefinger': 0.000
#   'advertised': 0.000
#   'fourteenth': 0.000
#   'signature': 0.000
#   'neat': 0.000
#   'male': 0.000
#   'interim': 0.000
#   'assured': 0.000
#   'conviction': 0.000
#   'clues': 0.000
#   'identity': 0.000
#   'disappearing': 0.000
#   'bedside': 0.000
#   'sufferer': 0.000
#   'dã©nouement': 0.000
#   'recesses': 0.000
#   'bisulphate': 0.000
#   'sideboard': 0.000
#   'tail': 0.000
#   'typewriter': 0.000
#   'fourteen': 0.000
#   'connivance': 0.000
#   'suspicion': 0.000
#   'loudly': 0.000
#   'deception': 0.000
#   'allusions': 0.000
#   'bitter': 0.000
#   'whip': 0.000
#   'stepfather': 0.000
#   'tinted': 0.000
#   'bushy': 0.000
#   'printed': 0.000
#   'whiskers': 0.000
#   'glasses': 0.000
#   'peculiarities': 0.000
#   '11.15': 0.000
#   'change': 0.000
#   'tickets': 0.000
#   'recent': 0.000
#   'particulars': 0.000
#   'largest': 0.000
#   'farms': 0.000
#   'society': 0.000
#   'neighbouring': 0.000
#   'mccarthys': 0.000
#   'race-meetings': 0.000
#   'families': 0.000
#   'spreading': 0.000
#   'employ': 0.000
#   'game-keeper': 0.000
#   'lodge-keeper': 0.000
#   'lake': 0.000
#   'lodge': 0.002
#   'grass': 0.001
#   'injuries': 0.000
#   'butt-end': 0.000
#   'inquest': 0.001
#   'coroner': 0.001
#   'police-court': 0.000
#   'culprit': 0.000
#   'military': 0.000
#   'angle': 0.000
#   'clouds': 0.000
#   'self-reproach': 0.000
#   'signs': 0.000
#   'local': 0.001
#   'sheet': 0.000
#   '3rd': 0.000
#   'groom': 0.000
#   'rabbit': 0.000
#   'sad': 0.000
#   'court': 0.000
#   'witness': 0.000
#   'discrepancy': 0.000
#   'cushioned': 0.000
#   'sympathy': 0.000
#   'jury': 0.000
#   'vanishing': 0.000
#   'hereford': 0.000
#   'plainer': 0.000
#   'gold-mines': 0.000
#   'prison': 0.000
#   'puny': 0.000
#   'glade': 0.000
#   'weekly': 0.000
#   'posterior': 0.000
#   'occipital': 0.000
#   'accused': 0.000
#   'older': 0.000
#   'hardihood': 0.000
#   'idiot': 0.000
#   'clutches': 0.000
#   'barmaid': 0.000
#   'bermuda': 0.000
#   'someone': 0.000
#   'crucial': 0.000
#   'estate': 0.000
#   'inferences': 0.000
#   'smokeless': 0.000
#   'court-yard': 0.000
#   'winding': 0.000
#   'veins': 0.000
#   'meadows': 0.000
#   'meadow': 0.000
#   'hatherley': 0.000
#   'private': 0.000
#   'wealthy': 0.000
#   'farther': 0.001
#   'site': 0.000
#   'reeds': 0.000
#   'stricken': 0.000
#   'trampled': 0.000
#   'gun': 0.000
#   'cloak': 0.000
#   'leaves': 0.000
#   'tree': 0.000
#   'moss': 0.000
#   'highroad': 0.000
#   'laughing-stock': 0.000
#   'lad': 0.001
#   "'cooee": 0.000
#   'appointment': 0.000
#   'rat': 0.000
#   'colony': 0.000
#   'definite': 0.000
#   'district': 0.000
#   'trifling': 0.000
#   'personality': 0.000
#   'injury': 0.000
#   'variety': 0.000
#   'cigar-holder': 0.000
#   'tip': 0.000
#   'cut': 0.000
#   'cord': 0.000
#   'grip': 0.000
#   'assizes': 0.000
#   'acting': 0.000
#   'diggings': 0.000
#   'bush': 0.000
#   'wagons': 0.000
#   'ballarat': 0.000
#   'swag': 0.000
#   'wagon-driver': 0.000
#   'market': 0.000
#   'keeping': 0.000
#   'bond': 0.000
#   'cover': 0.000
#   'easier': 0.000
#   'defending': 0.000
#   'records': 0.000
#   'paradol': 0.000
#   'grice': 0.000
#   'camberwell': 0.000
#   'equinoctial': 0.000
#   'routine': 0.000
#   'storm': 0.000
#   'fireplace': 0.000
#   'howl': 0.000
#   'gale': 0.000
#   'text': 0.000
#   'splash': 0.000
#   'streaming': 0.000
#   'south-west': 0.000
#   'tankerville': 0.000
#   'essential': 0.000
#   'commencement': 0.000
#   'blaze': 0.000
#   'invention': 0.000
#   'openshaw': 0.000
#   'war': 0.000
#   'states': 0.000
#   'negroes': 0.000
#   'republican': 0.000
#   'franchise': 0.000
#   'tradespeople': 0.000
#   'keys': 0.000
#   'attics': 0.000
#   'keyhole': 0.000
#   'laugh': 0.000
#   'gum': 0.000
#   'attic': 0.000
#   'horsham': 0.000
#   'lawyer': 0.000
#   'treble': 0.000
#   'deepest': 0.000
#   'terror': 0.000
#   'reception': 0.000
#   'repute': 0.000
#   'reconstruction': 0.000
#   'carpet-bag': 0.000
#   'january': 0.000
#   'outstretched': 0.000
#   'sundial': 0.000
#   'postmark': 0.000
#   'forts': 0.000
#   'chalk-pit': 0.000
#   'roads': 0.000
#   'snake': 0.000
#   'grasp': 0.000
#   'deaths': 0.000
#   'warnings': 0.000
#   'pips': 0.000
#   'pressing': 0.000
#   'guilty': 0.000
#   'meanwhile': 0.000
#   'mad': 0.000
#   'results': 0.000
#   'contemplation': 0.000
#   'reasoner': 0.000
#   'mud-stains': 0.000
#   'lumber-room': 0.000
#   "'american": 0.000
#   'charming': 0.000
#   'formidable': 0.000
#   'postmarks': 0.000
#   'probability': 0.000
#   'strong': 0.000
#   'threat': 0.000
#   'deed': 0.000
#   'mail-boat': 0.000
#   'deadly': 0.000
#   'senders': 0.000
#   'sailing-ship': 0.000
#   'holder': 0.000
#   'badge': 0.000
#   'ku': 0.000
#   'fanciful': 0.000
#   'civil': 0.000
#   'carolinas': 0.000
#   'terrorising': 0.000
#   'negro': 0.000
#   'murdering': 0.000
#   'marked': 0.000
#   'organisation': 0.000
#   'perpetrators': 0.000
#   'community': 0.000
#   'movement': 0.000
#   'page': 0.000
#   'miserable': 0.000
#   'dim': 0.000
#   'unopened': 0.000
#   'account': 0.000
#   'h': 0.000
#   'water-police': 0.000
#   'condition': 0.000
#   'riverside': 0.000
#   'embankment': 0.000
#   'direct': 0.000
#   'web': 0.000
#   'flies': 0.000
#   'loaf': 0.000
#   'hollow': 0.000
#   'cupboard': 0.000
#   'flap': 0.000
#   'gang': 0.000
#   'lone': 0.000
#   'union': 0.000
#   'ship': 0.000
#   'dundee': 0.000
#   'barque': 0.000
#   'vessels': 0.000
#   'port': 0.000
#   'albert': 0.000
#   'goodwins': 0.000
#   'stevedore': 0.000
#   'cable': 0.000
#   'orange': 0.000
#   'trough': 0.000
#   'theological': 0.000
#   'practice': 0.000
#   'wreck': 0.000
#   'clock': 0.000
#   'linoleum': 0.000
#   'surest': 0.000
#   'farthest': 0.000
#   'spell': 0.000
#   'dregs': 0.000
#   'docks': 0.000
#   'bar': 0.000
#   'ruffians': 0.000
#   'den': 0.000
#   'ceaseless': 0.000
#   'forecastle': 0.000
#   'newcomer': 0.000
#   'bowls': 0.000
#   'metal': 0.000
#   'vile': 0.000
#   'brazier': 0.000
#   'normal': 0.000
#   'opium': 0.000
#   'incoherent': 0.000
#   'rascally': 0.000
#   'moonless': 0.000
#   'vilest': 0.000
#   'clink': 0.000
#   'cedars': 0.000
#   'songs': 0.000
#   'current': 0.000
#   'belt': 0.000
#   '5.14': 0.000
#   'capital': 0.000
#   'aberdeen': 0.000
#   'continued': 0.000
#   'proprietor': 0.000
#   'lascar': 0.000
#   'toy': 0.000
#   'evident': 0.000
#   'cripple': 0.000
#   'wharves': 0.000
#   'windowsill': 0.000
#   'clothes': 0.000
#   'tide': 0.000
#   'villains': 0.000
#   'doings': 0.000
#   'greasy': 0.000
#   'harvest': 0.000
#   'outer': 0.001
#   'passers-by': 0.000
#   'lodger': 0.000
#   'sense': 0.000
#   'bleeding': 0.000
#   'ebbing': 0.000
#   'pockets': 0.000
#   'weighted': 0.000
#   'stripped': 0.000
#   'tell-tale': 0.000
#   'coat': 0.000
#   'act': 0.000
#   'fruits': 0.000
#   'coins': 0.000
#   'rush': 0.000
#   'questions': 0.000
#   'flood': 0.000
#   'gravesend': 0.000
#   'greyish': 0.000
#   'unexpected': 0.000
#   'summer': 0.000
#   'pipe': 0.000
#   'heap': 0.000
#   'previous': 0.000
#   'stable-boy': 0.000
#   'trap': 0.000
#   'bathroom': 0.000
#   'half-clad': 0.000
#   'lines': 0.000
#   'earliest': 0.000
#   'waterloo': 0.000
#   'stone-flagged': 0.000
#   'cells': 0.000
#   'grating': 0.000
#   'rent': 0.000
#   'grime': 0.000
#   'gladstone': 0.000
#   'bow': 0.000
#   'sleeper': 0.000
#   'water-jug': 0.000
#   'county': 0.001
#   'sponge': 0.000
#   'repulsive': 0.000
#   'tangled': 0.000
#   'exposure': 0.000
#   'pillow': 0.000
#   'cake': 0.000
#   'secrets': 0.000
#   'green-room': 0.000
#   'creditor': 0.000
#   'debt': 0.000
#   'dollars': 0.000
#   'keeper': 0.000
#   'evenings': 0.000
#   'coppers': 0.000
#   'compliments': 0.000
#   'season': 0.000
#   'ice': 0.000
#   'solution': 0.000
#   'punishment': 0.000
#   'shop': 0.000
#   'labyrinth': 0.000
#   'roughs': 0.000
#   'spoils': 0.000
#   'shape': 0.000
#   'bird': 0.000
#   'lining': 0.000
#   'goose': 0.000
#   'ultimate': 0.000
#   'unknown': 0.000
#   'individuality': 0.000
#   'tattered': 0.000
#   'brim': 0.000
#   'elastic': 0.000
#   'decline': 0.000
#   'forehead': 0.000
#   'excellent': 0.000
#   'foresight': 0.000
#   'moral': 0.000
#   'hat-securer': 0.000
#   'felt': 0.000
#   'lens': 0.000
#   'scissors': 0.000
#   'barber': 0.000
#   'gritty': 0.000
#   'fluffy': 0.000
#   'wearer': 0.000
#   'gas': 0.000
#   'countess': 0.000
#   'background': 0.000
#   'gem': 0.000
#   'dates': 0.000
#   '22nd': 0.000
#   'jewel-case': 0.000
#   'valuable': 0.000
#   'dressing-room': 0.000
#   'robbery': 0.000
#   'bureau': 0.000
#   'dressing-table': 0.000
#   'arrest': 0.000
#   'strongest': 0.000
#   'offence': 0.000
#   'sequence': 0.000
#   'crop': 0.000
#   'bad': 0.000
#   'approach': 0.000
#   'impulse': 0.000
#   'introduction': 0.000
#   'advertising': 0.000
#   'globe': 0.000
#   'banks': 0.000
#   'amoy': 0.000
#   'carbuncle': 0.000
# ...
#   'blithe': 0.000
#   'pigeon-hole': 0.000
#   'decided': 0.000
#   'ethereal': 0.000
#   'beyond': 0.000
#   'spiritual': 0.000
#   'cave-man': 0.000
#   'hopelessness': 0.000
#   'twitter': 0.000
#   'refuse': 0.000
#   'icy': 0.000
#   'ravings': 0.000
#   'remonstrance': 0.000
#   'fateful': 0.000
#   'cafe': 0.000
#   'bystanders': 0.000
#   'bandaged': 0.000
#   'hide': 0.000
#   'tobacco-slipper': 0.000
#   'bulletins': 0.000
#   'axiom': 0.000
#   'stitches': 0.000
#   'cunard': 0.000
#   'sublibrarian': 0.000
#   'saturday': 0.000
#   'hall-marks': 0.000
#   'hung-wu': 0.000
#   'yung-lo': 0.000
#   'writings': 0.000
#   'primitive': 0.000
#   'sung': 0.000
#   'yuan': 0.000
#   'published': 0.000
#   'ming': 0.000
#   'collection': 0.000
#   'connoisseur': 0.000
#   'transaction': 0.000
#   'emperor': 0.000
#   'shoso-in': 0.000
#   'languor': 0.000
#   'vitriol': 0.000
#   'she-devil': 0.000
#   'pawing': 0.000
#   'wages': 0.000
#   'cockaded': 0.000
#   'armorial': 0.000
#   'incriminating': 0.000
#   'rigid': 0.000
#   'boer': 0.000
#   'curmudgeon': 0.000
#   'steamer': 0.000
#   'veldt': 0.000
#   'roaring': 0.000
#   'rifles': 0.000
#   'boers': 0.000
#   'frank': 0.000
#   'spectator': 0.000
#   'astute': 0.000
#   'possible': 0.000
#   'detached': 0.000
#   'innkeeper': 0.000
#   'sultan': 0.000
#   'gravest': 0.000
#   'narratives': 0.000
#   'hall-table': 0.000
#   'gloves': 0.000
#   'smart': 0.000
#   'laughter': 0.000
#   'leper': 0.000
#   'educated': 0.000
#   'delinquent': 0.000
#   'lancet': 0.000
#   'apprehension': 0.000
#   'untidy': 0.000
#   'acid-charred': 0.000
#   'pipes': 0.000
#   'saturnine': 0.000
#   'irregularity': 0.000
#   'hundred-thousand-pound': 0.000
#   'drapery': 0.000
#   'alcove': 0.000
#   'gasogene': 0.000
#   'customary': 0.000
#   'diamond': 0.000
#   'boxer': 0.000
#   'minories': 0.000
#   'air-gun': 0.000
#   'dummy': 0.000
#   'nettle': 0.000
#   'beak': 0.000
#   'effigy': 0.000
#   'parasol': 0.000
#   'blymer': 0.000
#   'riviera': 0.000
#   'forged': 0.000
#   'trumps': 0.000
#   'unrestrained': 0.000
#   'restraint': 0.000
#   'hoffman': 0.000
#   'long-drawn': 0.000
#   'brains': 0.000
#   'faint': 0.000
#   'damned': 0.000
#   'dutchman': 0.000
#   'unwashed': 0.000
#   'imperturbable': 0.000
#   'weakness': 0.000
#   'painful': 0.000
#   'peer': 0.000
#   'well-worn': 0.000
#   'bruiser': 0.000
#   'spencer': 0.000
#   'moody': 0.000
#   'visitors': 0.000
#   'tenner': 0.000
#   'flushed': 0.000
#   '10': 0.000
#   'directory': 0.000
#   'labels': 0.000
#   'receiving-station': 0.000
#   'transmitter': 0.000
#   'paragraphs': 0.000
#   'garbage': 0.000
#   'turbid': 0.000
#   'orderly': 0.000
#   'geranium': 0.000
#   'cuts': 0.000
#   'heartless': 0.000
#   "'he": 0.000
#   "'belle": 0.000
#   'proudest': 0.000
#   'lamb': 0.000
#   'torture': 0.000
#   'publisher': 0.000
#   'mediaeval': 0.000
#   'wildly': 0.000
#   'assessment': 0.000
#   'yeggman': 0.000
#   'hammersmith': 0.000
#   'vampire': 0.000
#   'giver': 0.000
#   'importation': 0.000
#   'baby': 0.000
#   'assaults': 0.000
#   'cot': 0.000
#   'weak-minded': 0.000
#   'kiddies': 0.000
#   'chequers': 0.000
#   'wings': 0.000
#   'doorsteps': 0.000
#   'rebus': 0.000
#   'ceilings': 0.000
#   'uneven': 0.000
#   'half-panelled': 0.000
#   'peruvian': 0.000
#   'vet': 0.000
#   'curiosities': 0.000
#   'staircase': 0.000
#   'abandon': 0.000
#   'embrace': 0.000
#   'flaxen': 0.000
#   'cherub': 0.000
#   'dimpled': 0.000
#   'subjective': 0.000
#   'swiftest': 0.000
#   'venom': 0.000
#   'pillows': 0.000
#   'too': 0.000
#   '19th': 0.000
#   'penalties': 0.000
#   'arkansas': 0.000
#   'queerness': 0.000
#   'edgware': 0.000
#   'universality': 0.000
#   'alexandrian': 0.000
#   'adequate': 0.000
#   'nucleus': 0.000
#   'hans': 0.000
#   'blanks': 0.000
#   'basement': 0.000
#   'house-agent': 0.000
#   'buckboards': 0.000
#   'aggressor': 0.000
#   'caretaker': 0.000
#   'collector': 0.000
#   'prescott': 0.000
#   'sounder': 0.000
#   'counterfeiter': 0.000
#   'killer': 0.000
#   'clearness': 0.000
#   'education': 0.000
#   'narrowest': 0.000
#   'execrations': 0.000
#   'successful': 0.000
#   'scars': 0.000
#   'sallow': 0.000
#   'millionaire': 0.000
#   'passionate': 0.000
#   'frontal': 0.000
#   'stakes': 0.000
#   'reserve': 0.000
#   'amazon': 0.000
#   'reproof': 0.000
#   'thor': 0.000
#   'stonework': 0.000
#   'chip': 0.000
#   'parapet': 0.000
#   'neurotic': 0.000
#   'formalities': 0.000
#   'defence': 0.000
#   'appealing': 0.000
#   'hunted': 0.000
#   'toils': 0.000
#   'glance': 0.000
#   'innocence': 0.000
#   'fervour': 0.000
#   'unhappiness': 0.000
#   'schoolroom': 0.000
#   'all-important': 0.000
#   'god': 0.000
#   'cartridges': 0.000
#   'safety-catch': 0.000
#   'behaviour': 0.000
#   'sanity': 0.000
#   'under': 0.000
#   'workings': 0.000
#   'shag': 0.000
#   'index': 0.000
#   'throes': 0.000
#   'shyness': 0.000
#   'self-possession': 0.000
#   'reasoned': 0.000
#   'frankest': 0.000
#   'letter-basket': 0.000
#   'pathologist': 0.000
#   'temper': 0.000
#   'wolfhound': 0.000
#   'frenzied': 0.000
#   'effrontery': 0.000
#   'motto': 0.000
#   'scandal': 0.000
#   'tree-lined': 0.000
#   'commercial': 0.000
#   'prague': 0.000
#   'series': 0.000
#   'provisional': 0.000
#   'amenities': 0.000
#   'half-moon': 0.000
#   'mode': 0.000
#   'lamplit': 0.000
#   'ivy-covered': 0.000
#   'maddened': 0.000
#   'uproar': 0.000
#   'haemorrhage': 0.000
#   'treatment': 0.000
#   'serum': 0.000
#   'elixir': 0.000
#   'wondrous': 0.000
#   'himalayan': 0.000
#   'phial': 0.000
#   'poisons': 0.000
#   'sensual': 0.000
#   'worldly': 0.000
#   'survival': 0.000
#   'dreamer': 0.000
#   'monkey': 0.000
#   'pastime': 0.000
#   'coast-line': 0.000
#   'gables': 0.000
#   'paroxysm': 0.000
#   'students': 0.000
#   'plate-glass': 0.000
#   'chalk': 0.000
#   'incline': 0.000
#   'considerable': 0.000
#   'burberry': 0.000
#   'ill-usage': 0.000
#   'boats': 0.000
#   'thyme-scented': 0.000
#   'haven': 0.000
#   'mathematician': 0.000
#   'bellamys': 0.000
#   'downlands': 0.000
#   'deliberations': 0.000
#   'perception': 0.000
#   'bathing-pool': 0.000
#   'sand': 0.000
#   'burly': 0.000
#   "'lion": 0.000
#   'death-mark': 0.000
#   'mane': 0.000
#   'ripples': 0.000
#   'bite': 0.000
#   'cobra': 0.000
#   'bather': 0.000
#   'fearful': 0.000
#   'multitudinous': 0.000
#   'pulsation': 0.000
#   'disturbed': 0.000
#   'dispatch-cases': 0.000
#   'social': 0.000
#   'writers': 0.000
#   'discretion': 0.000
#   'choice': 0.000
#   'politician': 0.000
#   'lighthouse': 0.000
#   'fewest': 0.000
#   'buxom': 0.000
#   'clergy': 0.000
#   'abbas': 0.000
#   'rival': 0.000
#   'down': 0.000
#   'caravan': 0.000
#   'performance': 0.000
#   'food-carriers': 0.000
#   'roars': 0.000
#   'clown': 0.000
#   'berkshire': 0.000
#   'claw-marks': 0.000
#   'flaw': 0.000
#   'self-satisfied': 0.000
#   'sawdust': 0.000
#   'hoop': 0.000
#   'show': 0.000
#   'fines': 0.000
#   'leaden': 0.000
#   'palms': 0.000
#   'freaks': 0.000
#   'brave': 0.000
#   'eyepiece': 0.000
#   'zinc': 0.000
#   'seam': 0.000
#   'microscope': 0.000
#   'shoscombe': 0.000
#   'rents': 0.000
#   'derby': 0.000
#   'touts': 0.000
#   'jews': 0.000
#   'haunted': 0.000
#   'hated': 0.000
#   'visits': 0.000
#   'crypt': 0.000
#   'jockey': 0.000
#   'cinders': 0.000
#   'honest': 0.000
#   'mill-stream': 0.000
#   'extirpation': 0.000
#   'beloved': 0.000
#   'eagles': 0.000
#   'shafts': 0.000
#   'spaniel': 0.000
#   'lead': 0.000
#   'grass-lands': 0.000
#   'arched': 0.000
#   'mournful': 0.000
#   'coffin-plates': 0.000
#   'griffin': 0.000
#   'graves': 0.000
#   'sir': 0.000
#   'eighteenth': 0.000
#   'chapel': 0.000
#   'gothic': 0.000
#   'dropsy': 0.000
#   'coffins': 0.000
#   'morality': 0.000
#   'creditors': 0.000
#   'lucky': 0.000
#   'faithless': 0.000
#   'monotonous': 0.000
#   'poetry': 0.000
#   'weakling': 0.000
#   'snaky': 0.000
#   'deeply': 0.000
#   'plants': 0.000
#   'artistic': 0.000
#   'burden': 0.000
#   'haymarket': 0.000
#   'unused': 0.000
#   'blackheath': 0.000
#   'gay': 0.000
#   'fool': 0.000
#   'futility': 0.000
#   'roadside': 0.000
#   'intelligent': 0.000
#   'cellars': 0.000
#   'likely': 0.000
#   'water-pipes': 0.000
#   'strong-room': 0.000
#   'box-office': 0.000
#   'gas-pipe': 0.000
#   'ornamentation': 0.000
#   'tap': 0.000
#   'obviously': 0.000
#   'bi-weekly': 0.000
#   'concluding': 0.000
#   'death-chamber': 0.000
# State 'complete':
#   'sherlock': 0.009
#   'alteration': 0.009
#   '.': 0.161
#   'and': 0.036
#   'retribution': 0.009
#   'possession': 0.009
#   'hoax': 0.009
#   'confidence': 0.054
#   'mystery': 0.018
#   ';': 0.009
#   'change': 0.027
#   'happiness': 0.009
#   ',': 0.071
#   'manner': 0.009
#   'as': 0.009
#   'a': 0.018
#   'information': 0.009
#   'truth': 0.009
#   'silence': 0.018
#   'without': 0.009
#   'loss': 0.009
#   'wilderness': 0.009
#   'case': 0.018
#   'despair': 0.009
#   'my': 0.009
#   'stranger': 0.018
#   'suppression': 0.009
#   'mourning': 0.009
#   'ascendancy': 0.009
#   'the': 0.062
#   'view': 0.009
#   'confession': 0.009
#   'frankness': 0.018
#   'voluntary': 0.009
#   'which': 0.009
#   'register': 0.009
#   'sanity': 0.018
#   'bust': 0.009
#   'specimen': 0.009
#   'it': 0.009
#   'one': 0.009
#   'indifference': 0.009
#   'understanding': 0.009
#   'absence': 0.009
#   'influence': 0.009
#   'knowledge': 0.009
#   'maker': 0.009
#   'rather': 0.009
#   'love': 0.009
#   'mental': 0.009
#   'set': 0.027
#   'moral': 0.009
#   'in': 0.009
#   'satisfaction': 0.009
#   'list': 0.009
#   'record': 0.009
#   'rest': 0.018
#   'self-absorption': 0.009
#   'life': 0.009
#   'revenge': 0.009
#   'failures': 0.009
#   'attention': 0.009
# State 'sherlock':
#   'holmes': 0.945
#   'is': 0.002
#   '.': 0.014
#   "'s": 0.002
#   'everywhere': 0.002
#   ',': 0.017
#   'looked': 0.002
#   'has': 0.002
#   '!': 0.005
#   '?': 0.002
#   '--': 0.002
#   'and': 0.002
# State 'holmes':
#   'arthur': 0.000
#   'a': 0.001
#   'silver': 0.001
#   'the': 0.002
#   'preface': 0.001
#   'in': 0.007
#   'yet': 0.000
#   'is': 0.003
#   ',': 0.267
#   "'": 0.008
#   'seemed': 0.002
#   'followed': 0.001
#   'was': 0.029
#   '--': 0.006
#   'used': 0.000
#   'had': 0.035
#   '.': 0.207
#   'remarked': 0.003
#   'rose': 0.004
#   'sniffed': 0.000
#   ':': 0.003
#   'would': 0.003
#   'glanced': 0.005
#   'walked': 0.003
#   'approached': 0.000
#   'chuckled': 0.002
#   'took': 0.009
#   'curtly': 0.000
#   'led': 0.001
#   'with': 0.008
#   'laughed': 0.004
#   'broke': 0.001
#   'said': 0.002
#   'or': 0.000
#   'sharply': 0.000
#   'sprang': 0.005
#   'seated': 0.001
#   'and': 0.018
#   'gave': 0.004
#   ';': 0.009
#   'observed': 0.000
#   'answered': 0.008
#   'on': 0.001
#   'asked': 0.002
#   'drew': 0.002
#   'showed': 0.001
#   "'s": 0.038
#   'at': 0.001
#   'to': 0.004
#   'heartily': 0.000
#   'gives': 0.001
#   'placed': 0.001
#   'rubbed': 0.002
#   'shook': 0.006
#   'returned': 0.002
#   'put': 0.002
#   'unfolded': 0.000
#   'alone': 0.001
#   'leaned': 0.004
#   'declares': 0.000
#   '!': 0.018
#   'swung': 0.001
#   'whipped': 0.000
#   'advanced': 0.001
#   'knocked': 0.001
#   'bent': 0.001
#   '?': 0.035
#   'wanted': 0.000
#   'turned': 0.006
#   'then': 0.000
#   'clambered': 0.000
#   'looked': 0.006
#   'despatched': 0.000
#   'could': 0.001
#   'pouring': 0.000
#   'still': 0.001
#   'has': 0.001
#   'dejected': 0.000
#   'returning': 0.000
#   'here': 0.001
#   'ai': 0.000
#   'must': 0.000
#   'sitting': 0.000
#   'coud': 0.000
#   'eyed': 0.000
#   'smiled': 0.008
#   'quietly': 0.002
#   'she': 0.001
#   'lately': 0.000
#   'again': 0.001
#   'whistled': 0.002
#   'caught': 0.001
#   'dryly': 0.000
#   'slowly': 0.000
#   'without': 0.000
#   'scribbled': 0.001
#   'changed': 0.000
#   'dashed': 0.000
#   'as': 0.008
#   'from': 0.000
#   'by': 0.002
#   'staggered': 0.001
#   'rushed': 0.001
#   'coldly': 0.001
#   'were': 0.000
#   'pulled': 0.002
#   'sat': 0.009
#   'when': 0.002
#   'stopped': 0.003
#   'that': 0.001
#   'severely': 0.001
#   'fell': 0.001
#   'shot': 0.001
#   'blandly': 0.001
#   'welcomed': 0.000
#   'impatient': 0.000
#   'clapped': 0.002
#   'continued': 0.002
#   'suavely': 0.001
#   'stuck': 0.000
#   'thoughtfully': 0.001
#   'demurely': 0.000
#   'desired': 0.001
#   'traced': 0.000
#   'calmly': 0.000
#   'gently': 0.000
#   'gravely': 0.001
#   'after': 0.001
#   'cases': 0.000
#   'interposed': 0.000
#   'raved': 0.000
#   'moved': 0.000
#   'closed': 0.000
#   'grinned': 0.000
#   'more': 0.000
#   'drove': 0.001
#   'up': 0.000
#   'stooped': 0.001
#   'upon': 0.001
#   'twisted': 0.000
#   'pushed': 0.001
#   'carelessly': 0.000
#   'hailed': 0.001
#   'sweetly': 0.000
#   'cheerily': 0.001
#   'unlocked': 0.000
#   'sternly': 0.001
#   'standing': 0.001
#   'ran': 0.001
#   'nodded': 0.001
#   'refused': 0.001
#   'struck': 0.002
#   'gazed': 0.001
#   'laying': 0.000
#   'before': 0.001
#   'left': 0.001
#   'stepped': 0.001
#   'went': 0.000
#   'suddenly': 0.000
#   'rather': 0.000
#   'thrust': 0.001
#   'cut': 0.000
#   'threw': 0.001
#   'pricked': 0.001
#   'who': 0.001
#   'replaced': 0.001
#   'thought': 0.001
#   'shrugged': 0.004
#   'cocked': 0.000
#   'stood': 0.001
#   'impatiently': 0.000
#   'chuckling': 0.000
#   'picked': 0.002
#   'recovered': 0.000
#   'understood': 0.000
#   'stretched': 0.002
#   'waved': 0.001
#   'grunted': 0.000
#   'of': 0.001
#   'pacing': 0.000
#   'good-humoredly': 0.000
#   'handed': 0.001
#   'made': 0.003
#   'lay': 0.001
#   'into': 0.001
#   'wore': 0.000
#   'opened': 0.002
#   'i': 0.002
#   'next': 0.001
#   'ascended': 0.000
#   'flung': 0.000
#   'down': 0.000
#   'loved': 0.000
#   'during': 0.001
#   'sending': 0.000
#   'considered': 0.001
#   'strolled': 0.000
#   'takes': 0.000
#   'remained': 0.000
#   'ravenous': 0.000
#   'swallowed': 0.000
#   'edged': 0.000
#   'spoke': 0.001
#   'tore': 0.001
#   'forget': 0.000
#   'delivered': 0.000
#   'crouched': 0.001
#   'held': 0.003
#   'listened': 0.002
#   'inspected': 0.001
#   'interrupted': 0.001
#   'examined': 0.002
#   'very': 0.001
#   'preserved': 0.000
#   'liked': 0.000
#   'hurried': 0.001
#   'they': 0.000
#   'hunted': 0.000
#   'begged': 0.000
#   '[': 0.001
#   'pointed': 0.002
#   'dominated': 0.000
#   'can': 0.000
#   'dispatched': 0.000
#   'raised': 0.003
#   'whispered': 0.002
#   'folded': 0.000
#   'laid': 0.002
#   'also': 0.000
#   'disregarded': 0.000
#   'came': 0.001
#   'removed': 0.000
#   'entered': 0.001
#   'stole': 0.000
#   'unrolling': 0.000
#   'worked': 0.000
#   'slipped': 0.000
#   'tossed': 0.001
#   'sank': 0.001
#   'propped': 0.000
#   'spent': 0.001
#   'expected': 0.000
#   'suggested': 0.000
#   'stirred': 0.000
#   'halted': 0.001
#   'produced': 0.000
#   'an': 0.001
#   'lit': 0.001
#   'set': 0.001
#   'popped': 0.000
#   'sighed': 0.000
#   'burst': 0.000
#   'passed': 0.000
#   'tied': 0.000
#   'paused': 0.001
#   'darted': 0.001
#   'grasped': 0.000
#   'nestled': 0.000
#   'uttered': 0.000
#   'climbed': 0.000
#   'alluded': 0.000
#   'smoked': 0.001
#   'for': 0.001
#   'wrote': 0.001
#   'bowed': 0.000
#   'knew': 0.000
#   'plunged': 0.000
#   'leaning': 0.000
#   'inquired': 0.000
#   'muttered': 0.000
#   'mr.': 0.000
#   'whom': 0.000
#   'waited': 0.000
#   'did': 0.001
#   'bitterly': 0.000
#   'cast': 0.000
#   'himself': 0.001
#   'which': 0.001
#   'insisted': 0.000
#   'say': 0.000
#   'know': 0.000
#   'groaned': 0.001
#   'how': 0.000
#   'drily': 0.000
#   'breathed': 0.000
#   'discourses': 0.001
#   'murmured': 0.000
#   'flattened': 0.000
#   'helped': 0.000
#   'eagerly': 0.000
#   'dismissed': 0.000
#   'gleefully': 0.000
#   'sympathetically': 0.000
#   'until': 0.000
#   'brushed': 0.000
#   'will': 0.001
#   'read': 0.001
#   'over': 0.000
#   'added': 0.000
#   'sent': 0.000
#   'solemnly': 0.000
#   'twitched': 0.000
#   'talks': 0.000
#   'explained': 0.000
#   'meant': 0.000
#   'snorted': 0.000
#   'struggled': 0.000
#   'since': 0.000
#   'let': 0.000
#   'swept': 0.000
#   'softly': 0.000
#   'pried': 0.000
#   'absolutely': 0.000
#   'paid': 0.000
#   'tossing': 0.000
#   'through': 0.000
#   'gasped': 0.000
#   'consulted': 0.000
#   'soothed': 0.000
#   'firmly': 0.000
#   'half': 0.000
#   'cheerfully': 0.001
#   'plucked': 0.000
#   'paced': 0.000
#   'it': 0.001
#   'may': 0.001
#   'never': 0.000
#   'noted': 0.000
#   'now': 0.000
#   'knows': 0.000
#   'always': 0.000
#   'emerged': 0.000
#   'withdrew': 0.000
#   'seldom': 0.000
#   'discreetly': 0.000
#   'advised': 0.000
#   'balanced': 0.000
#   'resumed': 0.000
#   'there': 0.000
#   'reverted': 0.000
#   'promised': 0.000
#   'touched': 0.000
#   'rummaged': 0.000
#   'mentioned': 0.000
#   'earnestly': 0.000
#   'grimly': 0.000
#   'asking': 0.000
#   'discovered': 0.000
#   'brooded': 0.000
#   'all': 0.000
#   'assumed': 0.000
#   "''": 0.001
# State 'arthur':
#   'conan': 0.049
#   'charpentier': 0.024
#   'came': 0.024
#   'standing': 0.024
#   'morstan': 0.024
#   '.': 0.073
#   ',': 0.122
#   'and': 0.024
#   'were': 0.024
#   "'s": 0.073
#   'does': 0.024
#   'should': 0.024
#   'in': 0.024
#   'blinds': 0.024
#   'is': 0.024
#   'with': 0.024
#   'who': 0.024
#   'caught': 0.024
#   'had': 0.024
#   'pinner': 0.024
#   'harry': 0.024
#   '--': 0.024
#   'upon': 0.024
#   'to': 0.049
#   'fell': 0.024
#   'mounted': 0.024
#   'if': 0.024
#   'h.': 0.024
#   'willaby': 0.024
#   'cadogan': 0.024
#   'was': 0.024

# %% [markdown]
# # Generate new text

# %%
def random_walk(markov_chain: MarkovChain[TState], initial: TState) -> Iterable[TState]:
    current = initial

    while True:
        yield current

        next_states = list(markov_chain.get_state_transitions(current))
        next_weights = [markov_chain.get_transition_weight(current, next_state) for next_state in next_states]
        current = random.choices(next_states, next_weights, k=1)[0]

for i in itertools.islice(random_walk(markov_chain, "the"), 10):
    print(i, end=" ")

print()
# Out:
# the door which led to you know before it 's
